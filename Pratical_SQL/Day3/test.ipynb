# %%
import psycopg2

# %%
psycopg2.  __version__
# Out:
# '2.9.12 (dt dec pq3 ext lo64)'

# %%
from psycopg2 import connect

# %%
postgres_url='postgresql://postgres:SENHA@127.0.0.1:61701/railway'

# %%
from urllib.parse import urlparse

# %%
url=urlparse(postgres_url)

# %%
url
# Out:
# ParseResult(scheme='postgresql', netloc='postgres:SENHA@127.0.0.1:61701', path='/railway', params='', query='', fragment='')

# %%
conn=connect(host=url.hostname, port=url.port, user=url.username, password=url.password, database=url.path[1:])

# %%
cursor = conn.cursor()

# %%
cursor.execute("""
    CREATE TABLE cpus (
        id serial primary key,
        name varchar(255),
        cores int,
        threads int,
        prices decimal
    );
""")

# %%
conn.commit()
